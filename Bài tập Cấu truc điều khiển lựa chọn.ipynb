# %%
#W3A3
n=int(input("nhập n: "))
if n>0 and n& (n&(n-1))==0:
    print("n là lũy thừa của 2")
else:
    print("n không là lũy thừa của 2")
# Out:
# n là lũy thừa của 2

# %%
#W3A4
m,n=map(int,input("nhập m,n: ").split())
print(m//n)
# Out:
# 0

# %%
#W3A5
import math
m,n=map(float,input("nhập m,n: ").split())
chia=math.ceil(m/n)
print(chia)
# Out:
# 1

# %%
#W3A6
x=int(input("nhập x: "))
if x>0:
  if x%2==0:
    print("even")
  else:
    print("odd")
else:
    print("vui lòng nhập số dương")
# Out:
# vui lòng nhập số dương

# %%
#W3A7
a,b=map(int,input("nhập a,b: ").split())
if a<0 and b<0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
#W3A8
a=input("nhập chuỗi a: ")
b=input("nhập chuỗi b: ")
if len(a)>len(b):
    print("true")
else:
    print("false")
# Out:
# false

# %%
#W3A9
a,b,c=map(int,input("nhập a,b,c: ").split())
if a+b>c and a+c>b and b+c>a:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
#W3A10
a,b,c,d=map(int,input("nhập a,b,c,d: ").split())
print(max(a,b,c,d))
# Out:
# 90

# %%
#W3A11
a, b, c = map(int, input("Nhập a b c: ").split())
if a + b <= c or a + c <= b or b + c <= a:
    print("Không phải tam giác")
elif a == b == c:
    print("Tam giác đều")
elif a == b or b == c or a == c:
    print("Tam giác cân")
else:
    print("Tam giác thường")
# Out:
# Không phải tam giác

# %%
#W3A12
n=int(input("nhập n: "))
if n>0:
  if n%4==0 and n%100!=0 or n%400==0:
    print("yes")
  else:
    print("no")
else:
    print("vui lòng nhập số dương")
# Out:
# vui lòng nhập số dương

# %%
#W3A14
a,b=map(int,input("nhập a,b: ").split())
if a==0:
    if b==0:
        print("vô số nghiệm")
    else:
        print("vô nghiệm")
else:
    print("có nghiệm x=",round(-b/a,2))
# Out:
# có nghiệm x= -2.0

# %%
#W3A15
tb=float(input("nhập tb: "))
if tb>0:
   if tb>= 8.0:
      print( "Giỏi")
   elif tb>=6.5:
      print("Khá")
   elif tb>=5.0:
      print("Trung bình")
   else:  
      print("Yếu")
else:
    print("vui lòng nhập số dương")
# Out:
# Yếu

# %%
#W3A16
n=float(input("nhập n: "))
if n>=0:
    lam_tron=int(n+0.5)
    lam_tron_xuong= int(n)
    if n==int(n):
       lam_tron_len=int(n)
    else:
         lam_tron_len=int(n)+1
else:
    lam_tron=int(n-0.5)
    lam_tron_len= int(n)
    if n==int(n):
        lam_tron_xuong=int(n)
    else:
        lam_tron_xuong=int(n)-1
print(lam_tron,lam_tron_xuong,lam_tron_len)
# Out:
# -2 -3 -2

# %%
#W3A17
a,b,c,d=map(int,input("nhập a,b,c,d: ").split())
if a==0 or b%a!=0:
    print("không là cấp số nhân")
else:
    q=b//a
    if c*q==d and b*q==c:
        print("là cấp số nhân")
    else:
        print("không là cấp số nhân")
# Out:
# không là cấp số nhân
